# %%
import pandas as pd

dataset = {
    'Escenario': [1,2,3,4],
    'Ventas' : [10050,15000,10500,35000],
}

df = pd.DataFrame(dataset)
display(df)
# Out:
#    Escenario  Ventas
# 0          1   10050
# 1          2   15000
# 2          3   10500
# 3          4   35000
